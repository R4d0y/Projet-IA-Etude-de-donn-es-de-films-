# %% [markdown]
# # Analyse de données de films

# %% [markdown]
# Nous proposons de travailler sur des données décrivant des films. Les possibilités sont larges et vous êtes évalués sur vos propositions et votre méthodologie plus que sur vos résultats.
#
# Les données de départ sont disponibles sur:
# https://grouplens.org/datasets/movielens/
# au format CSV.
#
# Nous nous intéresserons en particulier au jeu de données: **MovieLens 20M Dataset**. Dans ce jeu de données, vous disposez entre autre de:
# * Idendifiant du film dans IMdb et TMdb (ça sera important ensuite)
# * Catégorie(s) du film
# * Titre du film
# * Notes données par les internautes aux films
#
# Afin de rendre le projet plus intéressant, nous ajoutons des données sur les acteurs et producteurs associés aux films (récupéré sur TMdb). Ces données sont disponibles sur les liens suivants:
#
# http://webia.lip6.fr/~guigue/film_v2.pkl <br>
# http://webia.lip6.fr/~guigue/act_v2.pkl <br>
# http://webia.lip6.fr/~guigue/crew_v2.pkl
#
# Ces fichiers contiennent respectivement : une nouvelle description des films (dont l'identifiant TMdb et la note moyenne donnée par les internautes, la date de sortie,...), une description des acteurs de chaque film et une description des équipes (scénariste, producteur, metteur en scène) pour chaque film.
#
# Ces données sont des listes de taille 26908, chaque élément de la liste correspondant à un dictionnaire dont vous étudierez les clés pour récupérer les informations utiles.
#
# **ATTENTION** Les contraintes de récupération d'informations en ligne font que la base MovieLens compte 27278 films mais les fichiers ci-dessus n'en comptent que 26908. Le plus simple est probablement d'éliminer les films de MovieLens qui ne sont pas dans cette seconde base.

# %% [markdown]
# ## Consignes générales pour l'analyse des données
#
# Vous devez proposer plusieurs analyses des données, qui devront à minima utiliser les
#  techniques suivantes:
#
# 1. Mettre en forme les données pour identifier les acteurs et les catégories, les indexer
# 1. Traiter au moins un problème de régression supervisé (par exemple la prédiction de la note moyenne donnée à un film par les internautes).
# 1. Traiter au moins un problème de classification supervisé (par exemple la prédiction de la catégorie d'un film)
# 1. Utiliser les données catégorielles (catégories, acteurs,...) de manière discrète ET de manière coninue (*dummy coding*) dans des approches différentes
# 1. Proposer au moins une approche de catégorisation non supervisée (pour regrouper les acteurs par exemple)
# 1. Mener une campagne d'expérience permettant de comparer les performances sur un problème en fonction des valeurs d'un paramètre (et donc, in fine, trouver la meilleure valeur du paramètre)
# 1. Proposer quelques illustrations

# %%
import numpy as np
import os
import pandas as pd
import matplotlib.pyplot as plt
import random
# %matplotlib inline
import pickle as pkl
# La ligne suivante permet de préciser le chemin d'accès à la librairie iads
import sys
sys.path.append('..')

# Importation de la librairie iads
import iads as iads

import sklearn

# importation de LabeledSet
from iads import LabeledSet as ls

# importation de Classifiers
from iads import Classifiers as cl

#importation de la fonction de kernel trick
from iads import KernelPolynomial as kerpoly

#importation de kmoyenne
from iads import kmoyenne as km

# %% [markdown]
# ## Chargement des données (base MovieLens + enrichissements)

# %%
# Chargement des données MovieLens
fname_links = os.path.abspath(r"C:\Users\Radoy\Documents\Projet3I026\3i026\ml-latest-small\movies.csv")
movies_set  = pd.read_csv(fname_links)
fname_links = os.path.abspath(r"C:\Users\Radoy\Documents\Projet3I026\3i026\ml-latest-small\ratings.csv")
ratings_set = pd.read_csv(fname_links)

# %%
# Chargement des données complémentaires
fname = os.path.abspath(r"C:\Users\Radoy\Documents\Projet3I026\3i026\ml-20m\act_v2.pkl")
acteurs_data = pkl.load(open(fname, "rb"))

fname = os.path.abspath(r"C:\Users\Radoy\Documents\Projet3I026\3i026\ml-20m\film_v2.pkl")
films_data = pkl.load(open(fname, "rb"))

fname = os.path.abspath(r"C:\Users\Radoy\Documents\Projet3I026\3i026\ml-20m\crew_v2.pkl")
crew_data = pkl.load(open(fname, "rb"))

# %% [markdown]
# ## Feature engineering
# A vous de créer les caractéristiques de description des données qui permettront d'améliorer les performances dans les tâches que vous aurez choisi d'aborder dans le projet.

# %%
# Faire un dictionnaire avec tous les acteurs (acteur => indice)
# + un dictionnaire inversé (indice => acteur)
actors = dict()
actors_inv = dict()
for lista in acteurs_data:
    for a in lista:
        # affecte une valeur à une clé si la clé n'est pas utilisée
        res = actors.setdefault(a['name'], a['gender'])
        if res == len(actors)-1:
            actors_inv[len(actors)-1] = a['name']

# Exemple de transformation supplémentaire
# Dans combien de films de base joue Tom Hanks? (Réponse 57)
# Dans combien de comédies...

# => On voit qu'il est possible de créer facilement des nouvelles caractéristiques qui
# apporteront des informations utiles pour certaines tâches

# %% [markdown]
# # Nous commencerons par faire une regression supervisé
# Pour cela nous allons utiliser d'abord comme donnees d'etude les categories d'un film.
#
# L'idee sera donc de pouvoir predire une note d'un film juste a partir de ses categories.
#
# La prediction est pour nous reussite si la valeur predite appartient a l'intervalle
# [score-0.5;score+0.5]

# %%
#A partir de la base movies.csv nous creons un tableau de tous les genres
genres = set(movies_set["genres"])
categories = set()
for i in genres:
    for j in i.split("|"):
        categories.add(j)
categories = list(categories)
categories.sort()
categories
# Out:
# ['(no genres listed)',
#  'Action',
#  'Adventure',
#  'Animation',
#  'Children',
#  'Comedy',
#  'Crime',
#  'Documentary',
#  'Drama',
#  'Fantasy',
#  'Film-Noir',
#  'Horror',
#  'IMAX',
#  'Musical',
#  'Mystery',
#  'Romance',
#  'Sci-Fi',
#  'Thriller',
#  'War',
#  'Western']

# %%
#Maintenant nous nous interessons aux scores moyens de chaque film 
ratings = ratings_set.sort_values("movieId")
ratings = ratings.groupby("movieId")["rating"].mean()
ratings.to_frame()
# Out:
#            rating
# movieId
# 1        3.920930
# 2        3.431818
# 3        3.259615
# 4        2.357143
# 5        3.071429
# 6        3.946078
# 7        3.185185
# 8        2.875000
# 9        3.125000
# 10       3.496212
# 11       3.671429
# 12       2.421053
# 13       3.125000
# 14       3.833333
# 15       3.000000
# 16       3.926829
# 17       3.776119
# 18       3.700000
# 19       2.727273
# 20       2.500000
# 21       3.494382
# 22       3.222222
# 23       3.125000
# 24       3.125000
# 25       3.625000
# 26       3.500000
# 27       3.333333
# 28       4.227273
# 29       4.013158
# 30       3.000000
# ...           ...
# 188189   4.500000
# 188301   3.666667
# 188675   3.500000
# 188751   4.500000
# 188797   4.000000
# 188833   4.500000
# 189043   2.500000
# 189111   3.000000
# 189333   3.750000
# 189381   2.500000
# 189547   1.000000
# 189713   2.500000
# 190183   3.500000
# 190207   1.500000
# 190209   4.000000
# 190213   1.000000
# 190215   1.500000
# 190219   1.000000
# 190221   1.000000
# 191005   4.500000
# 193565   3.500000
# 193567   3.000000
# 193571   4.000000
# 193573   4.000000
# 193579   3.500000
# 193581   4.000000
# 193583   3.500000
# 193585   3.500000
# 193587   3.500000
# 193609   4.000000
#
# [9724 rows x 1 columns]

# %%
#Le score moyen etant donc notre label nous pouvons commencer par creer
#notre labeled set
movies_LabeledSet = ls.LabeledSet(20)
for indx,row in movies_set.iterrows():
    table = [0]*20
    if row["movieId"] in ratings.keys():
        for i in row["genres"].split("|"):
            table[categories.index(i)] = 1
        movies_LabeledSet.addExample(table,ratings.at[row["movieId"]])

# %%
#Notre labeled set est donce cree, 
#nous pouvons commencer par faire notre perceptron

kp = kerpoly.KernelPolynomial()
training,predict = ls.split(0.6,movies_LabeledSet)
perceptron_projet= cl.ClassifierMoindreCarres(len(kp.transform(training.getX(0))),0.005,kp)

# %%
#Nous allons maintenant afficher comment evolue la precision
#de notre perceptron
accuracy = list()
for i in range(100):
    perceptron_projet.train(training,100)
    accuracy.append(perceptron_projet.accuracy(predict))

plt.plot([i for i in range(100)],accuracy)
plt.title('Evolution de l\'aprentissage')
plt.ylabel('Accuracy')
# Out:
# Text(0, 0.5, 'Accuracy')

# %% [markdown]
# La precision etant deux fois meilleurs que l'aleatoire, puisque l'on a une chance sur 5 (puisque le score est sur 5 et que la marge d'erreur est d'un point), nous nous sommes dit que si l'on anjoute pour chaque film la meilleur note de ses acteurs et la pire, la precision augmentera.

# %%
#Nous avons donc cree deux dictionnaires
# le premier acteurs_dans_film qui donne une liste d'acteurs pour chaque film
#le second permet d'avoir tous les acteurs de l'etude
acteurs_dans_film = dict()
tous_les_acteurs = set()
for index,row in movies_set.iterrows():
    liste_acteurs = list()
    for i in acteurs_data[index]:
        liste_acteurs.append(i['name'])
        tous_les_acteurs.add(i['name'])
    acteurs_dans_film[row['title']] = [liste_acteurs,[films_data[index].get('vote_average')]]

# %%
#Nous avons ecrit une fonction qui permettra d'avoir la liste
#des cles d'un dictionnaire en fonction d'une valeur
def getKeysByValue(dictOfElements, valueToFind):
    listOfKeys = list()
    listOfItems = dictOfElements.items()
    for item  in listOfItems:
        if valueToFind in item[1][0] :
            listOfKeys.append(item[0])
    return  listOfKeys

# %%
#Maintenant il suffit de donner a chaque acteur sa note moyenne
#Elle se calcule donc depuis la note de chaque film ou l'acteur a joue
dict_acteurs_moy = dict()
for i in tous_les_acteurs:
    films = getKeysByValue(acteurs_dans_film,i)
    som = 0
    for j in films:
        som += acteurs_dans_film.get(j)[1][0]
    if len(films) == 0:
        dict_acteurs_moy[i] = som/(len(films)+1)
    else:
        dict_acteurs_moy[i] = som/len(films)
dict_acteurs_moy
# Out:
# {'Rolfe Sedan': 7.62,
#  'Carl Gottlieb': 6.624999999999999,
#  'Makauly Guillermo': 7.3,
#  'Lorielle New': 5.366666666666667,
#  'Barbara Cupisti': 6.56,
#  'Joel Blake': 8.4,
#  'Al MacIntosh': 6.8,
#  'Richard Crane': 5.8,
#  'Ralph Cosham': 6.6,
#  'Midori Kiuchi': 7.4,
#  'Pepe Hern': 6.95,
#  'Joan Maude': 7.9,
#  'Eunice Gayson': 6.966666666666666,
#  'Mick Hucknall': 6.3,
#  'Tracy Middendorf': 6.550000000000001,
#  'Joe Gallagher': 6.2,
#  'Donald Nobles': 6.5,
#  'Cynthia Langbridge': 5.7,
#  'Enzo Andronico': 7.6,
#  'Bryan Chafin': 7.0,
#  'Toni Braxton': 6.7,
#  "Donald O'Brien": 6.8500000000000005,
#  'Otis Harlan': 6.733333333333333,
#  "Fiona O'Connor": 5.8,
#  'Jason David Frank': 5.05,
#  'Carlie Taylor': 7.2,
#  'Gerald McRaney': 6.25,
#  'Christopher J. Quinn': 5.7,
#  'DeForest Covan': 7.7,
#  'Jennifer Mayo': 5.9,
#  "Hugh O'Connell": 7.4,
#  'Lenore Banks': 6.5249999999999995,
#  'Elisabeth Senn': 5.9,
#  'Yuliet Ortega': 4.5,
#  'Holly Maples': 7.5,
#  'Altovise Davis': 5.2,
#  'Rachel Hayward': 6.0,
#  'Ervín Tomendál': 7.4,
#  'Mercedes Herrero': 6.1,
#  'Robert Bower': 4.6,
#  'Ric Anderson': 6.8,
#  'Richard Pachorek': 5.9,
#  'Steve Morris': 6.9,
#  'Livia Rasetti': 7.1,
#  'April Breneman': 7.8,
#  'Richard Tyson': 5.7125,
#  'Louis de Gonzague': 6.9,
#  'Maria Petz': 5.8,
#  'Pam Henry': 5.7,
#  'Dorothy Short': 4.1,
#  'Angelina Llongueras': 7.0,
#  'Sean Fenton': 5.8,
#  'Rachel Steinberg': 7.6,
#  'Melinda Clarke': 6.066666666666666,
#  'Lola Pashalinski': 6.2,
#  'Rini Bell': 6.766666666666667,
#  'Alison Seebohm': 7.3,
#  'Eric Meyers': 6.633333333333333,
#  'Aristide Caporale': 7.233333333333334,
#  'Mariya Poroshina': 6.2,
#  'Glenn Wrage': 8.1,
#  'Lutz Gabor': 7.5,
#  'Darren Drozdov': 7.9,
#  'Laura MacAulay': 5.6,
#  'Kurt Siegelin': 7.2,
#  'Alfred Edel': 7.449999999999999,
#  'Paul Batten': 6.7,
#  'Leslie Schofield': 7.5,
#  'José Medeiros': 6.6,
#  'Hazel Deane': 7.6,
#  'Brie Larson': 5.95,
#  'Lando Buzzanca': 6.95,
#  'Tarako': 7.95,
#  'Wilhelm Diegelmann': 7.5,
#  'John Ireland': 6.72,
#  'Brian Kerwin': 5.828571428571428,
#  'Sue Jones-Davies': 7.05,
#  'Guy Di Rigo': 6.5,
#  'Ben Carr': 7.2,
#  'Holly Near': 6.85,
#  'Joanne Boland': 6.0,
#  'Guy Grosso': 6.2,
#  'Abbas Kiarostami': 8.1,
#  'Robert Clapperton': 7.4,
#  'Roger Hampton': 6.4,
#  'Ralph Wright': 7.35,
#  'Charles Saynor': 7.0,
#  'Leyland Hodgson': 6.986666666666667,
#  'Allen Jung': 7.4,
#  'Krysta Carter': 7.1,
#  'Tiffany L. Addison': 5.6,
#  'Hank Garcia': 6.7,
#  'John Benfield': 6.9799999999999995,
#  'Titos Vandis': 6.471428571428572,
#  'Cara Lott': 6.7,
#  'Smaïn': 7.7,
#  'Claire Drouot': 7.2,
#  'Richard Cetrone': 5.866666666666667,
#  'Fritzi Jane Courtney': 5.65,
#  'Garry Goodrow': 6.2,
#  'Francie Swift': 6.933333333333334,
#  'Jackie Joseph': 6.533333333333334,
#  'Peter Baldwin': 6.95,
#  'Maria Charles': 5.2,
#  'Mari Rantasila': 5.9,
#  'Christy Cullen': 6.3,
#  'Eira Heath': 7.6,
#  'Maurice Maurin': 7.0,
#  'Joshua Halladay': 7.0,
#  'Heidi Sorenson': 6.5,
#  'Amy Birnbaum': 5.7,
#  'Józef Piekarski': 7.9,
#  'George Dvorsky': 7.7,
#  'Evan S. Evans': 7.3,
#  'Michael Gahr': 7.0,
#  'Kathleen Turner': 6.0375000000000005,
#  "Fred 'Snowflake' Toones": 7.5125,
#  'Lesli Kay': 4.5,
#  'Bruno Lastra': 6.199999999999999,
#  'Fateh Lohani': 6.5,
#  'Peter Stormare': 6.180769230769231,
#  "Beverly D'Angelo": 5.948,
#  'Robert Skjærstad': 6.8,
#  'Herbert C. Walton': 7.3,
#  'Elaine Stritch': 5.7125,
#  'Frankie Pine': 4.4,
#  'Audie Edmondson': 5.1,
#  'Lotte Bergstrøm': 4.9,
#  'Paul Lewitt': 7.2,
#  'Scott Paulin': 6.48888888888889,
#  'Yû Izumi': 7.4,
#  'Bill Elliott': 7.050000000000001,
#  'Esmond Ren Yi-Wan': 6.4,
#  'Sofie Gråbøl': 7.125,
#  'Dennis McCormack': 6.7,
#  'Paul Carr': 5.166666666666667,
#  'Harry Stewart': 6.5,
#  'Wilfred Hari': 8.0,
#  'Thomas Callaway': 6.7,
#  'James Hardie': 7.050000000000001,
#  'Brian Wimmer': 5.8999999999999995,
#  'Deborah Gates': 5.95,
#  'Lilyan Irene': 7.15,
#  'Douglas Spain': 5.760000000000001,
#  'Mary Griffin': 5.65,
#  'Pete Postlethwaite': 6.545833333333334,
#  'Takeyuki Hirai': 7.3,
#  'Alessandro Tedeschi': 6.9,
#  'Kim Wolfe': 4.9,
#  'Falko Schilling': 7.1,
#  'Richard Delmonte': 5.7,
#  'Jim Calvert': 6.1,
#  'Vincent Gallo': 6.449999999999999,
#  'Rinsaku Ogata': 7.099999999999999,
#  'Maghsood Moghadan': 7.7,
#  'Robert Cavanaugh': 5.2,
#  'Bjarne Hjelde': 5.5,
#  'Mark Feltch': 5.7,
#  'Diana Lynn': 6.666666666666667,
#  'Cheung Shui-Yeung': 7.9,
#  'Maria Mizar': 7.7,
#  'Dale Wilson': 6.266666666666667,
#  'Eric Poppick': 5.7,
#  'Lefty Lewis': 7.1,
#  'Michael Rizzo': 6.4,
#  'Will Klipstine': 6.9,
#  'Lo Lieh': 6.6,
#  'Crispian Belfrage': 6.9,
#  'Tamayo Perry': 5.7,
#  'Markus Hering': 0.0,
#  'Sheila Brothers': 7.6,
#  'Kristof Konrad': 6.8,
#  'Brad Perry': 6.8,
#  'Châu Belle Dinh': 6.1,
#  'Bowie Lam': 7.0,
#  'Jake Curran': 5.6,
#  'Richard Romanus': 6.144444444444446,
#  'Gabrielle Haker': 6.9,
#  'Melissa R. Stubbs': 3.8,
#  'Raul Gonzales': 7.0,
#  'Flavio de Flavis': 7.0,
#  'Roger Allam': 6.6,
#  'Bruce Bohne': 7.050000000000001,
#  'Wayne Kramer': 0.0,
#  'Kwai Ying Cheung': 5.5,
#  'Adrian Pasdar': 6.2,
#  'Barclay Hope': 6.066666666666667,
#  'William Tracy': 7.166666666666667,
#  'Ashley Eckstein': 4.6,
#  'Guy Way': 6.760000000000001,
#  'Marilyn Tokuda': 5.566666666666666,
#  'Ella La Cour': 7.5,
#  'Ed Quye': 6.8,
#  'Elisabeth Wagner': 3.6,
#  'Albert Insinnia': 4.8,
#  'Paul Koslo': 6.03,
#  'Swapan Mukherjee': 8.3,
#  'Mathieu Archer': 7.2,
#  'June Harris': 6.6,
#  'Tetyana Kryvytska Stang Lund': 5.0,
#  'Aleksei Kozodayev': 6.2,
#  'Vincenzo Barreca': 6.6,
#  'Erick Carrillo': 5.0,
#  'Tobin Wheeler': 6.4,
#  'Patricia Fugger': 5.5,
#  'June Smaney': 6.35,
#  'Philipp Weissert': 4.7,
#  'Lewis Arlt': 5.1,
#  'Jo McDonnell': 4.9,
#  'Paula Thomas': 6.2,
#  'George Chesebro': 7.1,
#  'Matthew J. Dunn': 7.4,
#  'Hye-jin Yu': 6.9,
#  'Teruo Matsuyama': 7.6,
#  'Nomadlozi Kubheka': 7.8,
#  'Lamberto Maggiorani': 8.149999999999999,
#  'Maria Cardinale': 6.2,
#  'Tim Kang': 5.400000000000001,
#  'Ronald Biggs': 7.0,
#  'Laurence Février': 6.5,
#  'Sue Casey': 6.933333333333334,
#  'Natalie Fesenko': 7.0,
#  'Anton Lesser': 6.039999999999999,
#  'Gregg Edelman': 6.58,
#  'Jaymee Ong': 6.8,
#  'Alex Ross': 6.35,
#  'Lucie Arnaz': 5.3,
#  'Philippe Bergeron': 6.4,
#  'Alan Solomon': 5.8,
#  'Irene Cagen': 5.5,
#  'Roy T. Anderson': 6.2,
#  'Esther Gorintin': 7.1,
#  'Jordana Brewster': 5.866666666666667,
#  'Peter Duncan': 6.1,
#  'Hal Torey': 4.6,
#  'Rik Mayall': 6.4,
#  'Tom Szekeres': 7.5,
#  'Stephanie Brooks': 6.8,
#  "Tim O'Connor": 6.050000000000001,
#  'Paul Dubov': 7.433333333333334,
#  'Hope Davis': 6.1812499999999995,
#  'Michael Matthys': 6.0,
#  'John Pinette': 4.75,
#  'Antti Ikkala': 7.3,
#  'Serge Thériault': 5.6,
#  'David Cropman': 6.2,
#  'Nabeel Kort': 6.3,
#  'Dinny Powell': 6.375,
#  'Kathryn Bundy': 5.7,
#  'Alexandre Hamidi': 7.0,
#  'Ben Shepherd': 7.0,
#  'Jack Watson': 6.575,
#  'Liz Morris': 4.3,
#  'Anthony J. Sacco': 7.9,
#  'David Ulmer': 6.050000000000001,
#  'Donna Pouget': 6.5,
#  'Arione De Winter': 5.9,
#  'Johnny Cuthbert': 5.3,
#  'Carl Reindel': 7.15,
#  'Don Terry': 7.3,
#  'James McIntyre': 6.2,
#  'Mikel Conrad': 5.466666666666666,
#  'Sampda Sharma': 5.9,
#  'Bryan Couture': 6.8,
#  'Colm Feore': 6.5,
#  'Chloe Sonnenfeld': 6.2,
#  'Danny Chow': 7.2,
#  'Elephant Man': 0.0,
#  'David Grotheim': 7.8,
#  'Glenn Lampert': 6.3,
#  'Vijay Amritraj': 5.8,
#  'Kadeem Hardison': 6.085714285714286,
#  'Brian Stokes Mitchell': 7.1,
#  'Heather Elizabeth Parkhurst': 3.7,
#  'Howard S. Herman': 6.6,
#  'Sylvester Morand': 5.8,
#  'Vladimir Seleznyov': 7.5,
#  'Charles Voelker': 6.5,
#  'Robert Okrzesik': 7.2,
#  'Darla Rae': 7.5,
#  'Brown Eyes': 6.8,
#  'Karl Heil': 7.8,
#  'Marjorie Card Hughes': 6.5,
#  'Pillow': 5.9,
#  'Colin Linden': 5.8,
#  'Devon Cole Borisoff': 7.8,
#  'Oliver Appelt Nielsen': 4.9,
#  'Bill Randolph': 5.75,
#  'Ge You': 7.366666666666666,
#  'Michael Cassidy': 6.666666666666667,
#  'Johnny Mask': 6.9,
#  'Erin Murphy': 5.6,
#  'Noel Wilton': 7.0,
#  'Carol Burnett': 6.42857142857143,
#  'Judi Goldhand': 5.5,
#  'Dennis King Jr.': 6.5,
#  'Ernesto Almirante': 7.7,
#  'Margot Kansten': 5.3,
#  'Franco Balducci': 7.6,
#  'Catherine Doucet': 7.6,
#  'Kôji Iwamoto': 8.4,
#  'Paul Buckby': 3.8,
#  'Edward S. Herman': 7.9,
#  'Cissy Meddings': 8.5,
#  'Scotty Morrow': 7.1,
#  'Kimberly Reeves': 5.8,
#  'Abdellatif Hamrouni': 7.1,
#  'Eoin Manley': 2.5,
#  'Mario Perrone': 6.5,
#  'Richard Ziman': 6.6,
#  'John Dicks': 6.9,
#  'Anna Maria Ferrero': 6.1,
#  'Andrew Connolly': 6.6,
#  'David Sawyer': 5.4,
#  'Dagmar Bláhová': 4.1,
#  'J. David Krassner': 6.3,
#  'Caio Junqueira': 7.533333333333334,
#  'Gérard Rudolf': 6.1,
#  'Constantine Hartofolis': 6.9,
#  'Veronica De Laurentiis': 7.3,
#  'Feliciano Tello Rossi': 6.1,
#  'Janice Frost': 5.5,
#  'Ashley Cemo': 6.9,
#  'Bobby Bass': 5.15,
#  'Edward Wiley': 6.225,
#  'Sidney Poitier': 6.786363636363637,
#  'Robert J. Groden': 7.7,
#  'Errica Poindexter': 7.3,
#  "Brian E. O'Neal": 6.8,
#  'Sam Simon': 6.3,
#  'Haruya Sakamoto': 8.200000000000001,
#  'Kim Jong-ho': 7.8,
#  'Rose McGowan': 5.49,
#  'Steve Eastin': 6.262499999999999,
#  'Karel Baetens': 7.3,
#  'Ray Walston': 6.289473684210526,
#  'Briony McRoberts': 6.9,
#  'Ousseynou Diop': 7.4,
#  'Bryan Coleman': 7.0,
#  'Nancy Price': 7.0,
#  'Chosuke Ikariya': 7.6,
#  'Alex Green': 5.8,
#  'Eddie Schwartz': 6.2,
#  "Robert 'Rock' Galotti": 6.6,
#  'Elisa Pugliese': 6.9,
#  "Matthew O'Toole": 4.0,
#  'Joanne Bradley': 4.5,
#  'Seidy López': 5.0200000000000005,
#  'Gil Birmingham': 4.0,
#  'Albert Riéra': 7.6,
#  'Gregory Polcyn': 6.0,
#  'Marie-Hélène Gagnon': 7.5,
#  'Matt Frewer': 5.64,
#  'Santos Morales': 6.4,
#  'Steve Cardenas': 5.05,
#  'Elliot M. Kaplan': 5.7,
#  'Drake Bell': 6.866666666666666,
#  'Rachel Bérendt': 7.7,
#  'Lea Brodie': 6.1,
#  'Everett Creach': 6.55,
#  'Luke Keltie': 6.8,
#  'Alan Ward': 7.9,
#  'Nanette Vallon': 7.466666666666666,
#  'Thuy An Luu': 7.0,
#  'George Renteria': 7.4,
#  'Tom Petty': 6.8,
#  'Arthur French': 6.066666666666666,
#  'Howard Ryshpan': 6.4,
#  'Simon Street': 5.6,
#  'Charles Ingram': 6.5,
#  'Michael Echols': 5.9,
#  'David Tse': 5.8,
#  'Wendelin Harston': 6.300000000000001,
#  'Tenzin Thuthob Tsarong': 7.0,
#  'Ronald J. Veres': 4.0,
#  'Choo': 6.2,
#  'William Hall': 6.466666666666666,
#  'Elisabeth Ruiz': 6.4,
#  'Leslie Hidula': 5.9,
#  'Harley Luse': 7.1,
#  'Forrest Landis': 6.2,
#  'Kjell-Hugo Grandin': 5.8,
#  'Emma Griffiths Malin': 6.699999999999999,
#  'Henry Brandon': 6.809090909090909,
#  'Josh Waters': 5.6,
#  'Joseph Vitale': 5.933333333333333,
#  'Kevin Gage': 6.474999999999999,
#  'Noah Fleiss': 6.3,
#  'Ivan Bekjarev': 7.7,
#  'Louis de Liso': 6.2,
#  'Jane Lambert': 6.2,
#  'Devlin': 5.2,
#  'Adoni Maropis': 5.95,
#  'Luis Martín Gil': 7.3,
#  'Matthew Price': 5.4,
#  'Joel Calendrillo': 8.4,
#  'Andrew Webster': 7.4,
#  'Kim Tae-woo': 7.7,
#  'Caroline Rhea': 5.199999999999999,
#  'Maria Cyliakus': 7.0,
#  'Hélène Mahieu': 6.4,
#  'Artro Morris': 5.9,
#  'Stanislaw Koczanowicz': 8.5,
#  'Isabel Ampudia': 5.5,
#  'Ron Diamond': 5.9,
#  'Jody Carter': 6.7,
#  'Aleksandr Tsybulsky': 7.4,
#  'Rob Paulsen': 6.175000000000001,
#  'Lou Ferguson': 5.8,
#  'Staffan Liljander': 7.2,
#  "David O'Connor": 8.1,
#  'Donavon Dietz': 5.0,
#  'Kelly Miracco': 5.4,
#  'Yūrei Yanagi': 6.6000000000000005,
#  'Justus von Dohnányi': 7.2,
#  'José Andrade': 6.0,
#  'Ellen Locy': 5.5,
#  'Joanna Gardner': 6.9,
#  'Holly Earl': 6.2,
#  'Helene Stanley': 6.65,
#  'Peter Saxe': 6.8,
#  'Tiny Ross': 6.7,
#  'Barry Letts': 7.3,
#  'Oliver Walpole': 6.4,
#  'Junior Almeida': 8.3,
#  'Baird Wallace': 6.1,
#  'Emi Ito': 6.6,
#  'Mary Kay Cook': 6.7,
#  'Gustav Vintas': 4.1,
#  'Stine Stengade': 4.9,
#  'Wally Walker': 7.4,
#  'Jenny Evans': 6.4,
#  'Johann Adam Oest': 3.5,
#  'Tabitha Soren': 7.3,
#  'György Gyõriványi': 6.8,
#  'Jason Clarke': 6.4,
#  'P. Dion Moore': 7.0,
#  'Cecil Humphreys': 7.05,
#  'Roscoe Orman': 6.566666666666666,
#  'Herschell Gordon Lewis': 6.3,
#  'Klaus Händl': 7.15,
#  'Joan Prather': 5.725,
#  'Idwig Stephane': 7.3,
#  'Barbara Slater': 8.1,
#  'Susie Malnik': 5.8,
#  'Aaron Lustig': 6.25,
#  'Kurt Christian': 6.4,
#  'Simon Ward': 6.616666666666666,
#  'Norman Salling': 7.7,
#  'Santo Santonocito': 7.8,
#  'Rowan Witt': 8.1,
#  'Gert Jacoby': 5.9,
#  'Kyle Meenan': 5.9,
#  'Peter Stebbings': 6.4,
#  'Guy-Daniel Tremblay': 7.4,
#  'Gisèle Trépanier': 6.9,
#  'William Gregory Lee': 5.25,
#  'Irene Kelly': 6.533333333333334,
#  'Scott McKenzie': 7.6,
#  'Sebastian Abineri': 7.2,
#  'Colm Coogan': 6.9,
#  'Lonnie James': 7.6,
#  'Jay Norris': 6.15,
#  'Thomas Bellin': 5.8,
#  'Vernon Dobtcheff': 6.728,
#  'Ley On': 7.8,
#  'Lloyd Dunn': 7.5,
#  'Setchin Kawaya': 6.85,
#  'Patrick Watt': 4.8,
#  'Yoshiko Miyazaki': 7.75,
#  'Bronagh Gallagher': 6.8,
#  'Steve Rassios': 5.8,
#  'Joe Bacino': 6.466666666666666,
#  'Fabiano Amato': 6.1,
#  'Curtiss Cook': 6.3,
#  'Todd Woodcroft': 6.6,
#  'Enrique Castillo': 5.9399999999999995,
#  'Slobodan Aligrudić': 7.8,
#  'Nikki Reed': 6.4,
#  'Henri Labussière': 7.0,
#  'Roscoe Karns': 7.0875,
#  'Jason Liggett': 6.8,
#  'Mary Portser': 6.1499999999999995,
#  'Erik Rondell': 6.15,
#  'Bob Babenia': 7.3,
#  'Eolo Capritti': 8.2,
#  'Dominique Lamure': 7.0,
#  'Norman Gregory': 7.2,
#  'Woody Eney': 6.233333333333333,
#  'Enrico Vecchi': 6.7,
#  'Patrick Muldoon': 5.8999999999999995,
#  'James Blackburn': 6.9,
#  'Bebe Daniels': 6.633333333333334,
#  'Taylor LaGrange': 6.7,
#  'Patricia Franklin': 7.6,
#  'Claudia Rieschel': 6.5,
#  'Sally Harper': 5.8,
#  'Ninetto Davoli': 7.4,
#  'F. Gary Gray': 6.9,
#  'Claudine Berg': 7.8,
#  'Michael Balston': 7.1,
#  "Erin O'Brien-Moore": 6.775,
#  'Zak Penn': 5.75,
#  'Alek Wek': 6.6,
#  'Francesca Santoro': 8.4,
#  'Bianca Pratt': 6.5,
#  'Jean Reno': 6.510000000000001,
#  'David Huffman': 5.875,
#  'Johnny Marlin': 7.2,
#  'Jan Williams': 7.1,
#  'Andrew Lauer': 5.975,
#  'Freda Kelly': 6.3,
#  'Guillaume Tardieu': 6.9,
#  'Deryck Barnes': 5.3,
#  'Naohisa Inoue': 7.8,
#  'Robert Nichols': 6.266666666666666,
#  'James Brolin': 6.264285714285714,
#  'Drakeel Burns': 7.3,
#  'Michael Burgess': 6.233333333333333,
#  'Cecilie A. Mosli': 7.1,
#  'Maurice Lenorman': 5.4,
#  'Simon Cadell': 6.25,
#  'Granville Redmond': 8.0,
#  'Philip Whitchurch': 6.8,
#  'Kate Zentall': 5.4,
#  'Gustavo Rangugni': 7.5,
#  'Freddie Highmore': 7.099999999999999,
#  'Ben Weber': 6.174999999999999,
#  'Matthew Shields': 6.8,
#  'Minami Takayama': 7.466666666666666,
#  'Frank Pietrangolare': 6.874999999999999,
#  'Sarah Smuts-Kennedy': 7.3,
#  'Louise Closser Hale': 7.080000000000001,
#  'Marlee Matlin': 6.1499999999999995,
#  'Martha Gibson': 6.9,
#  'Sylvia Ashton': 7.5,
#  'John Byner': 5.55,
#  'Richard Haydn': 7.266666666666667,
#  'Le Roy Seabrook': 7.0,
#  'Naotsugu Uzaki': 7.3,
#  'Tom Mardirosian': 6.3999999999999995,
#  'Garland Thompson': 6.5,
#  'Michi Azuma': 7.7,
#  'Morris Panych': 5.4,
#  'Mick Cunningham': 6.8,
#  'Rosa Maria Sardà': 6.859999999999999,
#  'Natasha Henstridge': 5.3999999999999995,
#  'Cathleen Bradley': 5.65,
#  'T. Max Graham': 6.05,
#  'Tracey Wilkinson': 7.25,
#  'Aubert Pallascio': 8.0,
#  'Gary Neilson': 7.6,
#  'Stacy Rukeyser': 4.4,
#  'Jon Huertas': 6.1,
#  'Mark Phelan': 6.299999999999999,
#  'Susie Trinh': 6.1,
#  'Vladimir Garin': 7.7,
#  'Robbie McGregor': 5.3,
#  'Guillaume Canet': 6.45,
#  'Bonnie Suggs': 6.3,
#  'Maya Bouma': 7.2,
#  'Robert La Tourneaux': 7.0,
#  'Sara Kestelman': 5.9,
#  'Adelaide João': 7.1,
#  'Peter Duray': 7.5,
#  'Alberto Vazquez': 8.3,
#  'Dick Warlock': 6.011111111111112,
#  'Bernard Wrigley': 6.433333333333334,
#  'José Hernán Rincón': 6.8,
#  'Matthew Michael Goodall': 7.4,
#  'Ivo Lopez': 5.3,
#  'Espen Hegnet Knudsen': 7.1,
#  'Prokhorenko': 7.6,
#  'Morris Carnovsky': 6.925,
#  'Zhang Fengyi': 7.533333333333334,
#  'Anne Ok': 5.1,
#  "George O'Hanlon Jr.": 6.3,
#  'Sergio Rubini': 7.06,
#  'Erik Jensen': 5.1000000000000005,
#  'Tone Loc': 5.6499999999999995,
#  'Virginia Pratt': 5.7,
#  'Daniel Raymont': 5.766666666666667,
#  'Bastien Vincent': 7.7,
#  'Kai J. Wong': 4.8,
#  'Bonaventura Ibáñez': 6.9,
#  'Maximilian Kesmodel': 5.3,
#  'Paul Blake': 8.2,
#  'Mickey Gilbert': 6.25,
#  'Karel Gult': 8.0,
#  'Darryl Henriques': 6.137499999999999,
#  'Ben Chaplin': 6.433333333333334,
#  'Ron Honthaner': 5.9,
#  'Matthew Long': 6.9,
#  'Luke Mably': 6.6,
#  'Daniël Boissevain': 6.5,
#  'Traci Adell': 6.5,
#  'Billy Ward': 6.8,
#  'Edward Kearns': 7.0,
#  'Stuart Saunders': 6.5249999999999995,
#  'Charlie G. Hawkins': 6.0,
#  'Richard McNamara': 7.9,
#  'Ann Hovey': 6.5,
#  'William Gates': 7.9,
#  'Nick Kosovich': 6.2,
#  'Thi Loc Truong': 7.4,
#  'Bob Peterson': 7.733333333333333,
#  'Martin Brest': 6.5,
#  'John Chandos': 7.0,
#  'Bob Frank': 5.6,
#  'Raphael Sbarge': 6.012499999999999,
#  'Wu Wanlu': 7.6,
#  'Lawrence Tierney': 6.276923076923077,
#  'Markus Klauk': 7.5,
#  'Sayuri Tanoue': 7.6,
#  'Damon Whitaker': 7.133333333333333,
#  'Alan Marshal': 6.916666666666667,
#  'He Sheng-Wei': 6.5,
#  'Stuart Holmes': 6.875,
#  'Jennifer Lee Pryor': 6.1,
#  'Melissa Rayworth': 5.3,
#  'Gotaro Tsunashima': 6.5,
#  'Nikki Plant': 6.7,
#  'Charles Grant': 5.6,
#  'Robert Axelrod': 6.3,
#  'Karlos Drinkwater': 8.2,
#  'Olivier Beer': 6.1,
#  'David Canal': 5.5,
#  'John Hoey': 5.9,
#  'Pierre Franckh': 7.066666666666666,
#  'Phyllis Konstam': 5.65,
#  'Peter Atkins': 5.5,
#  'Kellie Hudson': 6.4,
#  'Stanley Ross': 6.6,
#  'Takashi Taniguchi': 7.3,
#  'Heinie Conklin': 6.8428571428571425,
#  'Ron Lynch': 7.1,
#  'Joyce Hemson': 6.3,
#  'Neal Dodd': 7.65,
#  'Hattie Noel': 7.1,
#  'William Law': 6.699999999999999,
#  'Hal Ketchum': 6.7,
#  'Melanie Manos': 6.0,
#  'Casey Siemaszko': 6.500000000000001,
#  'Kimberly Brickland': 5.7,
#  'De La Soul': 6.8,
#  'Ben Talar': 8.5,
#  'Eric Weinstein': 6.75,
#  'Richard Kruspe': 5.8,
#  'Kam Ray Chan': 5.3,
#  'Yan Epstein': 6.4,
#  'Earl Holliman': 6.8999999999999995,
#  'Paul Barber': 6.7749999999999995,
#  'Zach Minkoff': 5.3,
#  'Sharmagne Leland-St. John': 6.949999999999999,
#  'Jean Hill': 6.8,
#  'Olaf Ussing': 8.3,
#  'Mimi Broadhead': 6.5,
#  'Nathan Jones': 6.7,
#  'Mitch Carter': 5.833333333333333,
#  'Michael Crane': 5.66,
#  'Thomas Kopache': 6.211111111111111,
#  'Cyril Thornton': 7.050000000000001,
#  'James Timmons': 6.9,
#  'Tokyo Ernie': 7.2,
#  'Dan Butler': 6.410000000000001,
#  'Jennifer Cooke': 5.9,
#  'Gillian Kearney': 6.8,
#  'Tina Chen': 4.633333333333334,
#  'Claude Bessy': 7.4,
#  'Stephen Barker Turner': 4.3,
#  'Marilyn Chris': 6.800000000000001,
#  'Eve Plumb': 6.6,
#  'Bud Jamison': 7.4,
#  'Ozzy Osbourne': 6.114285714285714,
#  'Shend': 6.2,
#  'Art Linkletter': 6.6,
#  'Wolfgang Grindemann': 7.0,
#  'Julien Guiomar': 7.266666666666667,
#  'Canned Heat': 7.5,
#  'Gloria Delaney ': 5.2,
#  'Bernie Styles': 7.8,
#  'Patti Morse': 5.0,
#  'Mandy Rimer': 6.3,
#  'Terry Herrington': 4.3,
#  'Marilyn Leubner': 5.9,
#  'Catalina Botello': 6.2,
#  'Rocco Lerro': 6.6,
#  'James Gandia': 5.6,
#  'Alley Mercedes': 5.8,
#  'Alfredo Raino': 7.6,
#  'Charles Lane': 6.8478260869565215,
#  'Brittany Murphy': 6.083333333333334,
#  'Stephen Ferry': 7.166666666666667,
#  'Deborah Hobart': 6.125000000000001,
#  'Roy Hudd': 6.9,
#  'Kathleen Chalfant': 6.2375,
#  'H. Richard Greene': 6.6,
#  'Barry Woolgar': 6.7,
#  'Arturo Cobo': 8.1,
#  'Peter Doyle': 7.0,
#  'Ian Dury': 6.0600000000000005,
#  'Glenda Jackson': 6.362500000000001,
#  'Steve Nuke': 4.8,
#  'Daniel London': 6.675,
#  'Walter Catlett': 7.116666666666666,
#  'Dock P. Ellis Jr.': 6.0,
#  'George Lloyd': 7.066666666666666,
#  'Eric Morgan Stuart': 6.6,
#  'Denise Hunt': 5.6,
#  'Eamonn Doyle': 7.2,
#  "Fred O'Dell": 6.9,
#  'Tonya Goodson': 1.7,
#  'John A. MacKay': 6.4,
#  'Doug Roberts': 6.266666666666666,
#  'Tamara Gorski': 6.033333333333334,
#  'Virginia Hey': 6.9,
#  'Jacqi Loewy': 5.7,
#  'María Celedonio': 6.0,
#  'Nando Bruno': 8.149999999999999,
#  'Deanna Bond': 6.1,
#  'Ryô Nishida': 7.3,
#  'René Lavan': 6.033333333333334,
#  'Oribe': 7.0,
#  'Barbara Nesser': 6.5,
#  'Herbert Sutch': 7.300000000000001,
#  'Corey William May': 5.5,
#  'Reamy Hall': 6.0,
#  'John Fergusson': 6.1,
#  'Will Welch': 6.0,
#  'Helen Eby-Rock': 6.8,
#  'George Peppard': 6.422222222222222,
#  'Per Fritzell': 5.550000000000001,
#  'Eduard Linkers': 6.65,
#  'Chief Dave Beautiful Bald Eagle': 4.0,
#  'Kongar-ol Ondar': 6.4,
#  'Pia Ingemann Petersen': 7.1,
#  'Gerald Castillo': 4.95,
#  'Pamela Everett': 6.5,
#  'Constance Cummings': 7.1,
#  'Kelli Williams': 7.2,
#  'Colleen Winton': 5.2,
#  'Shaby Ben-Aroya': 5.9,
#  'John Garfield': 6.957142857142857,
#  'Richard Rebiere': 6.1,
#  'Jim Jenkins': 8.4,
#  'Ross Harris': 6.4,
#  'Scott Getlin': 5.949999999999999,
#  'Ethan Phillips': 6.07,
#  'Alvin Greenman': 6.800000000000001,
#  'Kathalina Veniero': 4.5,
#  'Art Farmer': 7.3,
#  'Juan Martín Gravina': 5.0,
#  'Monte St. James': 6.2,
#  'Magussi Shimanuki': 5.6,
#  'Florence Midgley': 6.6,
#  'Sage Parker': 7.1,
#  'Michael McKean': 5.807692307692308,
#  'Jean-Pierre Mas': 5.6,
#  'Russell G. Jones': 6.5,
#  'Ian Black': 6.8,
#  'Alan Donnes': 7.7,
#  'Nick Stahl': 6.054545454545454,
#  'Richard Ooms': 6.5,
#  'Lucy Webb': 6.3,
#  'Charlotte Austin': 6.9,
#  'Harold Perrineau': 6.407692307692307,
#  'Jodi Cohen': 4.8,
#  'Ophelia M. Turner': 6.1,
#  'Tania Riabouchinskaya': 5.7,
#  'Peter Lenaeku': 7.3,
#  'Erica Gimpel': 6.716666666666666,
#  'Alexander Zemeckis': 7.3,
#  'Earl Clyde': 7.3,
#  'Carol Ohmart': 7.0,
#  'Yayoi Maki': 7.1,
#  'René Liu': 6.8,
#  'Carolyn Fitzsimmons': 4.3,
#  'Beth Littleford': 6.2,
#  'Paul Westphal': 6.45,
#  'Richard Gonzales': 5.4,
#  'Kyle Sabihy': 6.050000000000001,
#  'David Croft': 7.7,
#  'Kellye Nakahara': 5.966666666666666,
#  'Randall Deal': 7.4,
#  'Melinda Betron': 5.5,
#  'Arthur Roberts': 5.4750000000000005,
#  'Roberto Della Casa': 6.3,
#  'Yann Trégouët': 6.1,
#  'Sean Albertson': 7.5,
#  "Ronald 'Too Small' Small": 0.0,
#  'Alexander Morton': 6.15,
#  'Ladislav Krečmer': 6.0,
#  'Bill Raymond': 6.405555555555555,
#  'Sandrine Dumas': 5.55,
#  'Katsuji Mori': 7.55,
#  'Nina Totenberg': 6.5,
#  'Tony Danza': 5.2,
#  'Phillip Brown': 6.1,
#  'Florence Muller': 6.7,
#  'Viv Leacock': 5.466666666666666,
#  'Gino Barbacane': 7.7,
#  'Jutta Schaad': 7.1,
#  'Gary Hendrickson': 6.8,
#  'Joost Wynant': 6.3,
#  'Gary Grimes': 6.166666666666667,
#  'Russell Horton': 6.333333333333333,
#  'Penny Riley': 5.6,
#  'Shin Ibuki': 7.6,
#  'Petr Krusalnicky': 6.3,
#  'Merritt Butrick': 6.35,
#  "John O'May": 6.3,
#  'Noam Jenkins': 5.733333333333333,
#  'Cameron Finley': 6.166666666666667,
#  'Regis Toomey': 6.7733333333333325,
#  'Ben Ratner': 5.2,
#  'Beau Dremann': 5.95,
#  'Charles Robinson': 6.622222222222221,
#  'Devon Gummersall': 4.6,
#  'Helen Prejean': 7.4,
#  'Ugo Tognazzi': 6.449999999999999,
#  'Veronica Bruni': 7.1,
#  'Patrick Wright': 5.5,
#  'David Bowie': 6.8999999999999995,
#  'Donna Reed': 6.58,
#  'Dan Malloy': 7.2,
#  'Jim Francis': 5.7,
#  'Laura Linney': 6.833333333333334,
#  'Jacky Cohen': 7.8,
#  'Paul Sotoff': 5.9,
#  'Viviane Chantel': 7.6,
#  'Jung Woo-sung': 6.9,
#  'Victoria Thomas': 6.6,
#  'J.J. Toba': 6.0,
#  'Howie Seago': 7.1,
#  'Tyreese Burnett': 6.3,
#  'Bruce Lyons': 6.2,
#  'Keram Malicki-Sánchez': 6.6000000000000005,
#  'Wolfgang Stumpf': 6.8,
#  'Karen Black': 5.982142857142859,
#  'Clara Reid': 7.0,
#  'Achileas Skevis': 7.6,
#  'Skip McClendon': 6.8,
#  'Mike Parsons': 7.2,
#  'Dang Taai-Woh': 7.6,
#  'Premsinee Ratanasopha': 6.0,
#  'Bridgette Kerkove': 6.4,
#  'Kira Daniels': 6.5,
#  'James C. Lewis': 4.8,
#  'Sean Bridgers': 6.300000000000001,
#  'Desiree Gould': 6.2,
#  'Brandis Kemp': 6.5,
#  'Liz Davies': 6.5,
#  'Ailene Herring': 7.3,
#  'Yasar Güner': 6.8,
#  'Sonny James': 1.5,
#  'Kool Moe Dee': 4.9,
#  'Mary Webster': 6.9,
#  'Gertrude Olmstead': 6.7,
#  'Daniel Lee Smith': 7.2,
#  'Thomas F. Evans': 6.3,
#  'Colleen McQuade': 5.0,
#  'Uwe Kockisch': 7.2,
#  'Pavel Cajzl': 6.3,
#  'Dietrich Frauboes': 6.8,
#  'Akemi Ueno': 7.9,
#  "Brían F. O'Byrne": 6.383333333333334,
#  'Victor Callender': 3.8,
#  'Victor Cox': 7.4,
#  'Annick Danis': 7.4,
#  'Abel Gance': 7.3,
#  'Kid Creole': 5.6,
#  'Doug Dearth': 6.8,
#  'Carme Elias': 7.1,
#  'Françoise Lugagne': 7.3,
#  'Cindy Fisher': 7.7,
#  'Leon Deavers': 6.4,
#  'Victor Kilian': 7.0699999999999985,
#  'Rennie Campbell': 7.2,
#  'Jerry Potter': 6.45,
#  'Doan Viet Ha': 6.949999999999999,
#  'Philippe Dehesdin': 7.2,
#  'Hitoshi Ozawa': 6.833333333333333,
#  'Nancy Abrahams': 6.3,
#  'Brendan Fraser': 5.812,
#  'Thomas Fiss': 7.8,
#  'Renée Asherson': 7.040000000000001,
#  'Layke Anderson': 6.9,
#  'Milo Rafi': 5.9,
#  'Cathy Meils': 6.5,
#  'Tôru Abe': 8.45,
#  'Aki Aleong': 5.92,
#  'David Miller': 4.8,
#  'Tania Palaiologou': 7.9,
#  'Philip Wood': 5.8,
#  'Alexander Hammid': 7.6,
#  'Stephen Geoffreys': 6.1,
#  'Allison Forster': 7.0,
#  'James Komack': 6.550000000000001,
#  'Fang Qing-Zhuo': 6.0,
#  'Ziya Babai': 7.2,
#  'Emma Penella': 7.3,
#  'Jim Ferguson': 5.6,
#  'Kanji Ôsugi': 8.5,
#  'Nelson Hall': 8.2,
#  'Piero Mazzinghi': 7.9,
#  'Shakara Ledard': 5.6000000000000005,
#  'Michiyo Bandô': 5.9,
#  'Orn-anong Panyawong': 6.7,
#  'Lew Bracker': 6.2,
#  'George Bedard': 6.5,
#  'Daniel E. Smith': 7.1,
#  'Andi Garrett': 6.6,
#  'Hope Clarke': 6.25,
#  'Earl Mohan': 7.9,
#  'Gonzalo Suárez': 7.5,
#  'Luca Bonicalzi': 6.7,
#  'Kliment Denchev': 6.6,
#  'Josef Swickard': 3.75,
#  'Angelo R. Sales': 6.5,
#  'Scott Cumberbatch': 6.6,
#  'Robin Raymond': 6.4,
#  'David Milford': 6.6,
#  'Keith Brunsmann': 6.0,
#  'Monique Vermont': 7.1,
#  'William Graves': 7.0,
#  'Madison Brandon': 5.8,
#  'Stig Eldred': 6.1,
#  'Paul Guerro': 5.7,
#  'Joe Regalbuto': 6.1000000000000005,
#  'John Detoro': 6.2,
#  'Felicia Atkins': 6.1,
#  'Declan Croghan': 7.7,
#  'Dan Meaden': 6.0,
#  'Joanne Jordan': 7.1,
#  'Michael J. Lyons': 7.9,
#  'Marcel Marceau': 6.2,
#  'Rosa Furman': 6.8,
#  'Armelia McQueen': 6.35,
#  'Victoria Hernández Sanguino': 6.7,
#  'Nikolaj Coster-Waldau': 6.780000000000001,
#  'Michael Feinstein': 5.7,
#  'Malila Saint Duval': 6.4,
#  'Jared Van Snellenberg': 6.5,
#  'Natalie Rogers': 6.0,
#  'Kevin Trainor': 6.6,
#  'Dorian Healy': 5.6,
#  "April O'Brien": 6.4,
#  'Christophe Rossignon': 7.15,
#  'Alison Wiegert': 7.5,
#  'Christine Healy': 5.75,
#  'Jean-Marie Juan': 6.550000000000001,
#  'Maury Chaykin': 6.134285714285714,
#  'Eleanor Powell': 6.8999999999999995,
#  'Kimberly Lynn': 5.7,
#  'Vyacheslav Butusov': 7.5,
#  'Marek Vašut': 6.1000000000000005,
#  'Elizabeth Ann Feeley': 6.6,
#  'André Ekyan': 7.6,
#  'Despo Diamantidou': 7.3,
#  'Marie Dejaer': 7.1,
#  "'Lee' George Quinones": 7.4,
#  'Mario Porfito': 7.2,
#  'Helen Foster': 6.5,
#  'Sally Day': 6.5,
#  'Michael Beck': 5.875,
#  'Mark Priolo': 5.6,
#  'Lisa Davis': 7.0,
#  'Nadra Lamloum': 5.0,
#  'Wai-Ho Yung': 6.5,
#  'Susan Hegarty': 7.4,
#  'James Hayes Liboiron': 6.0,
#  'Marja-Leena Junker': 6.7,
#  'Andrew Bennett': 6.9,
#  'Charles Santy': 7.2,
#  'Doug E. Fresh': 7.0,
#  'Miles Marsico': 6.4,
#  'Jewel Jaffe': 7.0,
#  'Valerio Esposito': 7.0,
#  'Zhao Yuxiu': 7.8,
#  'George Eagles': 7.6,
#  'Burt Neuborne': 6.9,
#  'Bradley Lavelle': 6.0600000000000005,
#  'Trini López': 7.7,
#  'Glenn Colerider': 5.8,
#  'John Cusack': 6.604761904761904,
#  'Callie Thorne': 4.66,
#  'Tammie M. Tignor': 6.0,
#  'Hubie Kerns': 7.5,
#  'Gadarukanaru Taka': 7.05,
#  'Anny Chasson': 5.5,
#  'Chuck Montgomery': 5.2,
#  'Alex Karras': 6.6571428571428575,
#  'Athol Fugard': 7.55,
#  'John Warburton': 6.35,
#  'Taina Elg': 5.666666666666667,
#  'Alice Nunn': 6.3,
#  'Walt Flanagan': 6.6000000000000005,
#  'Aleksa Palladino': 6.449999999999999,
#  'Dolores Calò': 6.7,
#  'Samantha Murray': 5.5,
#  ...}

# %%
#Nous sommes maintenant pret a creer notre labeledset
movies_set_ameliore = ls.LabeledSet(22)
for indx,row in movies_set.iterrows():
    table = [0]*20
    if row["movieId"] in ratings.keys() and row['title'] in acteurs_dans_film.keys():
        for i in row["genres"].split("|"):
            table[categories.index(i)] = 1
        notes_acteurs =list()
        for i in acteurs_dans_film[row['title']][0]:
            notes_acteurs.append(dict_acteurs_moy[i])
        if len(notes_acteurs)>0:
            table.append(max(notes_acteurs)/10.0)
            table.append(min(notes_acteurs)/10.0)
            movies_set_ameliore.addExample(table,ratings.at[row["movieId"]])

# %%
training_2,predict_2 = ls.split(0.6,movies_set_ameliore)
perceptron_projet= cl.ClassifierMoindreCarres(len(kp.transform(training_2.getX(0))),0.01,kp)

# %%
accuracy = list()
for i in range(100):
    perceptron_projet.train(training_2,10)
    accuracy.append(perceptron_projet.accuracy(predict_2))

plt.plot([i for i in range(100)],accuracy)
plt.title('Evolution de l\'aprentissage')
plt.ylabel('Accuracy')
# Out:
# Text(0, 0.5, 'Accuracy')

# %% [markdown]
# ## Place a la classification supervisé
# Nous decidons donc de predire le genre d'un acteur a partir de:
# * la note moyenne des films ou il a joue
# * le nombre de films dans lesquels il a joue
# * Le nombre de film joue pour chaque categorie

# %%
def categorie(liste_films):
    liste = [0]*20
    for i in liste_films:
        for genre in movies_set.loc[movies_set['title']==i]["genres"].values[0].split("|"):
            liste[categories.index(genre)]+=1
    return liste

# %%
def anneeMoyenne(listeDeFilm):
    moyenne=0
    for i in listeDeFilm:
        something=film_data.loc[film_data['original_title']==i]
        if len(something)>0:
            moyenne+=int(something['release_date'].values[0].split("-")[0])
    return moyenne/(len(listeDeFilm)*1.0)/1000

# %%
acteurs_lSet = ls.LabeledSet(4)
for i in dict_acteurs_moy.keys():
    les_films = getKeysByValue(acteurs_dans_film,i)
    if actors[i]==2:
        label = 1
    else:
        label=-1
    acteurs_lSet.addExample(np.array([dict_acteurs_moy[i],len(les_films)]+categorie(les_films)),[label])

# %%
train_acteurs,predict_acteurs = ls.split(0.6,acteurs_lSet)

# %%
clStoc = cl.ClassifierPerceptronKernelStochastique(len(kp.transform(acteurs_lSet.getX(0))),0.00001,kp)

# %%
accuracy_acteurs = list()
for i in range(100):
    clStoc.train(train_acteurs,100)
    accuracy_acteurs.append(clStoc.accuracy(predict_acteurs))

plt.plot([i for i in range(100)],accuracy_acteurs)
plt.title('Evolution de l\'aprentissage')
plt.ylabel('Accuracy')
# Out:
# Text(0, 0.5, 'Accuracy')

# %% [markdown]
# Nous nous sommes demande si la classification s'ameliore si l'on ajoute en plus l'annee de sortie du film.

# %%
film_data = pd.DataFrame(films_data)

# %%
def anneeMoyenne(listeDeFilm):
    moyenne=0
    for i in listeDeFilm:
        something=film_data.loc[film_data['original_title']==i]
        if len(something)>0:
            moyenne+=int(something['release_date'].values[0].split("-")[0])
    if len(listeDeFilm)>0:
        return moyenne/(len(listeDeFilm)*1.0)/1000
    return 0

# %%
acteurs_lSet_v2 = ls.LabeledSet(23)
for i in dict_acteurs_moy.keys():
    les_films = getKeysByValue(acteurs_dans_film,i)
    anneMoy = anneeMoyenne(les_films)
    if actors[i]==2:
        label = 1
    else:
        label=-1
    concat = [dict_acteurs_moy[i],len(les_films),anneMoy]+categorie(les_films)
    acteurs_lSet_v2.addExample(concat,label)

# %%
train_acteurs_v2,predict_acteurs_v2 = ls.split(0.6,acteurs_lSet_v2)

# %%
clStoc2 = cl.ClassifierPerceptronKernelStochastique(len(kp.transform(acteurs_lSet_v2.getX(0))),0.00001,kp)

# %%
accuracy_acteurs = list()
for i in range(100):
    clStoc2.train(train_acteurs_v2,100)
    accuracy_acteurs.append(clStoc2.accuracy(predict_acteurs_v2))

plt.plot([i for i in range(100)],accuracy_acteurs)
plt.title('Evolution de l\'apprentissage')
plt.ylabel('Accuracy')

# %% [markdown]
# # Clustering
# Nous nous sommes demander si l'on peut regrouper les utilisateurs qui ont notes les films.
#
# Nous avons donc eu l'idee de prendre deux categories qui different un npeu: l'action et la romance. Puis nous avons regroupe pour chaque utilisateur la note moyenne des films d'action qu'il a donne et celle des films de romance.

# %%
genre_ratings = pd.DataFrame()

for genre in ["Action","Romance"]:
    genre_movies = movies_set[movies_set["genres"].str.contains(genre)]
    avg_rating_per_genre = ratings_set[[i in genre_movies['movieId'] for i in ratings_set['movieId']]].loc[:,['userId','rating']].groupby(['userId'])['rating'].mean().round(2)
    genre_ratings = pd.concat([genre_ratings,avg_rating_per_genre],axis=1)

# %%
genre_ratings.columns = ['avg_rating_action','avg_rating_romance']

# %%
genre_ratings = genre_ratings[np.isfinite(genre_ratings[genre_ratings.columns[0]])]
genre_ratings = genre_ratings[np.isfinite(genre_ratings[genre_ratings.columns[1]])]

# %% [markdown]
# Nous avons supprime les notes qui sont dans l'intervalle [2.5;3.5], que nous avons juge inutile pour notre etude.

# %%
genre_ratings = genre_ratings.drop(genre_ratings[(genre_ratings['avg_rating_action'] >= 2.5) \
                                                 & (genre_ratings['avg_rating_action'] <= 3.5)].index)

# %%
genre_ratings = genre_ratings.drop(genre_ratings[(genre_ratings['avg_rating_romance'] >= 2.5) \
                                                 & (genre_ratings['avg_rating_romance'] <= 3.5)].index)

# %%
genre_ratings = genre_ratings.drop('userId',axis=1)

# %% [markdown]
# Nous avons utilise en premier l'algorithme des KMeans que nous avons implante dans les tme 8 et 9.

# %%
centroides_3, clustering_3 = km.kmoyennes(7,genre_ratings,0.05,100)
km.affiche_resultat(genre_ratings,centroides_3,clustering_3)

# %% [markdown]
# Puis nous nous sommes dis pourquoi pas utiliser la bibliotheque sklearn, pour comparer nos resultats.

# %%
print(__doc__)

from time import time
import numpy as np
import matplotlib.pyplot as plt

from sklearn import metrics
from sklearn.cluster import KMeans
from sklearn.datasets import load_digits
from sklearn.decomposition import PCA
from sklearn.preprocessing import scale

data = np.array(genre_ratings)

n_samples, n_features = data.shape


# #############################################################################
# Visualize the results on PCA-reduced data


kmeans = KMeans(init='k-means++', n_clusters=7, n_init=10)
kmeans.fit(data)

# Step size of the mesh. Decrease to increase the quality of the VQ.
h = .02     # point in the mesh [x_min, x_max]x[y_min, y_max].

# Plot the decision boundary. For that, we will assign a color to each
x_min, x_max = data[:, 0].min() - 1, data[:, 0].max() + 1
y_min, y_max = data[:, 1].min() - 1, data[:, 1].max() + 1
xx, yy = np.meshgrid(np.arange(x_min, x_max, h), np.arange(y_min, y_max, h))

# Obtain labels for each point in mesh. Use last trained model.
Z = kmeans.predict(np.c_[xx.ravel(), yy.ravel()])

# Put the result into a color plot
Z = Z.reshape(xx.shape)
plt.figure(1)
plt.clf()
plt.imshow(Z, interpolation='nearest',
           extent=(xx.min(), xx.max(), yy.min(), yy.max()),
           cmap=plt.cm.Paired,
           aspect='auto', origin='lower')

plt.plot(data[:, 0], data[:, 1], 'k.', markersize=2)
# Plot the centroids as a white X
centroids = kmeans.cluster_centers_
plt.scatter(centroids[:, 0], centroids[:, 1],
            marker='x', s=169, linewidths=3,
            color='w', zorder=10)


plt.show()
